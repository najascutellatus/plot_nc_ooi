# %%
"""
@author Mike Smith
@email michaesm@marine.rutgers.edu
@Purpose To create an interactive time series plot for OOI data utilizing the datashader andbokeh module. This doesn't render an
@ actual plot, but rather an html containing interactiveSVG elements. This can ONLY run on your computer in an ipynb.
@ This script works very well for creating meaningful representations of large datasets.
@ Install datashader to your condaenv using: conda install -c bokeh datashader
"""
import xarray as xr
import datashader as dsp
import datashader.transfer_functions as tf
import os
import bokeh.plotting as bp
from datashader.bokeh_ext import InteractiveImage
bp.output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0c90d4ea-bebc-49b1-8482-0eea04ed4737">Loading BokehJS ...</span>
#     </div>

# %%
file_dir = '/Users/mikesmith/Documents/files/'
file_name = 'deployment0001_CE02SHBP-LJ01D-06-CTDBPN106-streamed-ctdbp_no_sample_20140925T181758.928831-20141109T235959.511873.nc'
file = os.path.join(file_dir, file_name)

var = 'ctdbp_no_seawater_pressure'

# %%
ds = xr.open_dataset(file, decode_times=False)
df = ds[var].to_dataframe()

# %%
x_range = (df['time'].min(), df['time'].max())
y_range = (df[var].min(), df[var].max())

# %%
# Create functions to generate new base_plot on zoom
def create_image(x_range=x_range, y_range=y_range, w=500, h=500):
    cvs = dsp.Canvas(x_range=x_range, y_range=y_range, plot_height=h, plot_width=w)
    agg = cvs.line(df, 'time', var, agg=dsp.any())
    return tf.shade(agg)


def base_plot(tools='pan,wheel_zoom,box_zoom,save,reset'):
    p = bp.figure(tools=tools, plot_width=800, plot_height=600,
                  x_range=x_range, y_range=y_range, outline_line_color=None,
                  min_border=0, min_border_left=0, min_border_right=0,
                  min_border_top=0, min_border_bottom=0)
    p.xgrid.grid_line_color = None
    p.ygrid.grid_line_color = None
    return p

p = base_plot()
InteractiveImage(p, create_image)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="7aae9064-3230-43e2-b1cf-6a81720437af"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("7aae9064-3230-43e2-b1cf-6a81720437af").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("a4c74b1c-4cae-4c27-88ee-5f1b2494e87e", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("7aae9064-3230-43e2-b1cf-6a81720437af");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '7aae9064-3230-43e2-b1cf-6a81720437af' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"856bc660-5f2c-4a9f-9dd7-b92f0a1d97e8":{"roots":{"references":[{"attributes":{"formatter":{"id":"e3c420bb-5cb3-4a97-bbc0-7171bd999ed0","type":"BasicTickFormatter"},"plot":{"id":"4f6c7d1a-1b36-40fd-9011-7a2dce7a2db7","subtype":"Figure","type":"Plot"},"ticker":{"id":"659f6ee1-6ee7-4bc2-b198-abf8064a8cbf","type":"BasicTicker"}},"id":"09c7d83b-32ec-44db-ad1c-11cdb4a8b16d","type":"LinearAxis"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"4f6c7d1a-1b36-40fd-9011-7a2dce7a2db7","subtype":"Figure","type":"Plot"},"ticker":{"id":"67061de6-490a-4319-9b54-a2b06906649a","type":"BasicTicker"}},"id":"6f3f0cc7-febd-420b-85ee-ed5101ecfc98","type":"Grid"},{"attributes":{},"id":"bda491f3-a0a1-4efd-8f2c-4dabb37f2e87","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"abf59bd9-61d5-4f42-acee-a1b07da8976b","type":"PanTool"},{"id":"8ffbd064-25f2-4506-84cc-fcd2c8845845","type":"WheelZoomTool"},{"id":"18be1aa4-a6b2-472c-8e13-1cfaf591c046","type":"BoxZoomTool"},{"id":"91eb267b-6bef-4d83-913b-92b5302d58fc","type":"SaveTool"},{"id":"e7d53bab-b0b2-467c-9b63-5d81e51b702e","type":"ResetTool"}]},"id":"b4068975-c8e5-4f56-bbbe-39bdd24845be","type":"Toolbar"},{"attributes":{"formatter":{"id":"bda491f3-a0a1-4efd-8f2c-4dabb37f2e87","type":"BasicTickFormatter"},"plot":{"id":"4f6c7d1a-1b36-40fd-9011-7a2dce7a2db7","subtype":"Figure","type":"Plot"},"ticker":{"id":"67061de6-490a-4319-9b54-a2b06906649a","type":"BasicTicker"}},"id":"98dbd471-3ed0-419f-ab75-b2713b2e3eee","type":"LinearAxis"},{"attributes":{},"id":"d9321b87-5964-4dcd-9ace-c32257184de8","type":"ToolEvents"},{"attributes":{"args":{"x_range":{"id":"545b161f-e30a-43a8-931a-f2c159d43202","type":"Range1d"},"y_range":{"id":"1f9befaa-79ce-4245-bade-c6b949a408d8","type":"Range1d"}},"code":"\n        // Define a callback to capture errors on the Python side\n        function callback(msg){\n          if (msg.msg_type == \"execute_result\") {\n            if (msg.content.data['text/plain'] === \"'Complete'\") {\n               if (Bokeh._queued.length) {\n                   update_plot();\n               } else {\n                   Bokeh._blocked = false;\n               }\n               Bokeh._timeout = Date.now();\n            }\n          } else {\n            console.log(\"Python callback returned unexpected message:\", msg)\n          }\n        }\n        callbacks = {iopub: {output: callback}};\n\n        function update_plot() {\n            range = Bokeh._queued;\n            var cmd = \"from datashader.bokeh_ext import InteractiveImage; InteractiveImage._callbacks['a4c74b1c-4cae-4c27-88ee-5f1b2494e87e'].update(\" + range + \")\"\n            // Execute the command on the Python kernel\n            if (IPython.notebook.kernel !== undefined) {\n                var kernel = IPython.notebook.kernel;\n                kernel.execute(cmd, callbacks, {silent : false});\n            }\n            Bokeh._queued = [];\n        }\n\n        var plot = x_range.plots[0];\n        // Generate a command to execute in Python\n        var ranges = {xmin: x_range.attributes.start,\n                       ymin: y_range.attributes.start,\n                       xmax: x_range.attributes.end,\n                       ymax: y_range.attributes.end,\n                       w: Math.floor(plot.width),\n                       h: Math.floor(plot.height)}\n        var range_str = JSON.stringify(ranges)\n\n        if (!Bokeh._queued) {\n            Bokeh._queued = [];\n            Bokeh._blocked = false;\n            Bokeh._timeout = Date.now();\n        }\n\n        timeout = Bokeh._timeout + 2000;\n        if (typeof _ === \"undefined\") {\n        } else if ((Bokeh._blocked && (Date.now() < timeout))) {\n            Bokeh._queued = [range_str];\n        } else {\n            Bokeh._queued = [range_str];\n            setTimeout(update_plot(), 200);\n            Bokeh._blocked = true;\n            Bokeh._ ...
